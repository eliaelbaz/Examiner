# %%
import pandas as pd
# 5
customers = pd.read_csv('customers.csv')
items = pd.read_csv('items.csv')
orders = pd.read_csv('orders.csv')
order_item = pd.read_csv('order_item.csv')

customers.info()
items.info()
orders.info()
order_item.info()

customers.describe(include='all')
items.describe(include='all')
orders.describe(include='all')
order_item.describe(include='all')

customers.head()
items.head()
orders.head()
order_item.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            500 non-null    int64
#  1   first_name    494 non-null    object
#  2   last_name     494 non-null    object
#  3   gender        447 non-null    object
#  4   age           475 non-null    float64
#  5   nationallity  494 non-null    object
#  6   joining_date  439 non-null    object
#  7   phone_number  500 non-null    object
#  8   email         500 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 35.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 50 non-null     int64
#  1   item_name          50 non-null     object
# ...

# %%
# 6
items = pd.read_csv('Items.csv')
items['NonNullCount'] = items.notnull().sum(axis=1)
items_sorted = items.sort_values(by=['item_name', 'NonNullCount'], ascending=[True, False])
items_deduplicated = items_sorted.drop_duplicates(subset='item_name', keep='first')
items_deduplicated = items_deduplicated.drop(columns=['NonNullCount'])
items_deduplicated
# Out:
#     id            item_name                   item_category  item_price  \
# 0   26        Action Camera           Photography Equipment     2694.25
# 1   37   Antivirus Software                        Software     4186.62
# 2   11       Blu-Ray Player     Video Players and Recorders     3382.86
# 3   25            Camcorder           Photography Equipment      860.01
# 4    7               Camera           Photography Equipment     2366.72
# 7   18     Computer Monitor       Computers and Accessories     4076.35
# 8   27          Dash Camera           Photography Equipment     1283.99
# 9    3              Desktop       Computers and Accessories     1121.84
# 11  24                Drone        Televisions and Displays     4449.99
# 14  21  External Hard Drive       Computers and Accessories     1251.36
# 15  15      Fitness Tracker  Mobile Devices and Accessories     2997.29
# 16  30         Gaming Chair                Gaming Equipment      417.16
# ...

# %%
# 7
items['NonNullCount'] = items.notnull().sum(axis=1)
items_sorted = items.sort_values(by=['item_name', 'NonNullCount'], ascending=[True, False])
items_deduplicated = items_sorted.drop_duplicates(subset='item_name', keep='first')
id_mapping = items_sorted[['id', 'item_name']].merge(
    items_deduplicated[['id', 'item_name']], on='item_name', suffixes=('_old', '_new')
)
order_item['item_id'] = order_item['item_id'].replace(
    id_mapping.set_index('id_old')['id_new']
)
items_deduplicated.drop(columns=['NonNullCount'], inplace=True)
items_deduplicated
order_item.head()
# Out:
# C:\Users\eliae\AppData\Local\Temp\ipykernel_14496\2644578553.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   items_deduplicated.drop(columns=['NonNullCount'], inplace=True)
#    id  order_id  item_id  quantity
# 0   1       337     24.0         2
# 1   2       430     27.0         6
# 2   3       430     36.0         2
# 3   4       508     46.0         1
# 4   5       229     27.0         2

# %%
# 8
customers['MissingCount'] = customers.isnull().sum(axis=1)
customers_cleaned = customers[customers['MissingCount'] < 3].copy()
customers_cleaned.drop(columns=['MissingCount'], inplace=True)
customers_cleaned
# Out:
#       id first_name  last_name  gender   age   nationallity joining_date  \
# 0      1      Eadie     Maffeo  Female  41.0         France   11/01/2022
# 1      2     Hammad  Brewerton    Male  56.0         Isreal   30/09/2022
# 2      3    Terrell       Bris    Male  43.0          India          NaN
# 3      4    Frannie   Morewood    Male  84.0         France   26/05/2021
# 4      5      Sophi      Fleet  Female  33.0         Sweden   19/07/2021
# ..   ...        ...        ...     ...   ...            ...          ...
# 495  496     Renado     Monard    Male  53.0          India          NaN
# 496  497     Kalina       Luno  Female  30.0          Italy   16/10/2022
# 497  498        Viv  Callander  Female  44.0         France   24/02/2021
# 498  499      Georg      Raper    Male  41.0        Germany   24/04/2022
# 499  500   Richardo   O'Criane    Male  32.0  United States   06/08/2021
#
#      phone_number                      email
# 0    534-341-9052        emaffeo0@smh.com.au
# ...

# %%
# 9
order_item_merged = pd.merge(order_item, customers[['id']], left_on='id', right_on='id', how='left')
order_item_cleaned = order_item_merged[~order_item_merged['id'].isin(removed_customers)]
order_item_cleaned
# Out:
#        id  order_id  item_id  quantity
# 0       1       337     10.0         2
# 1       2       430     27.0         6
# 2       3       430     36.0         2
# 3       4       508     46.0         1
# 4       5       229     27.0         2
# ..    ...       ...      ...       ...
# 995   996       594     24.0         2
# 996   997       330     32.0         8
# 997   998       472     10.0         3
# 998   999       222     29.0         1
# 999  1000       337     16.0         1
#
# [994 rows x 4 columns]
